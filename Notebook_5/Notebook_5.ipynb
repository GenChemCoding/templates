# %% [markdown]
# <a href="https://colab.research.google.com/github/mari6-commits/templates/blob/main/Notebook_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Gases

# %% [markdown]
# Here is the ideal gas law:
# $PV = nRT$
#
# Where...
# P: Pressure
# V: volume
# n: number of moles
# R: gas constant
# T: absolute temp in kelvin

# %%
# %pip install mendeleev RDkit GenChemCoding_package
# Out:
# ...
#   Using cached mendeleev-1.1.0-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached rdkit-2026.3.3-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 9.4 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.2/37.2 MB 43.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.8/865.8 kB 42.8 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.text as txt
import matplotlib.font_manager as fm
from matplotlib.textpath import TextToPath
from matplotlib.patches import Circle
import numpy as np
import pandas as pd
import GenChemCoding_package as gcp

# %%
T = gcp.convert_to_k(100, 'F')
print(T)
# Out:
# 310.93

# %%
R = gcp.ideal_gas_constant('c^3', 'Torr')
print(R)
# Out:
# 8.3145

# %%
print(gcp.ideal_gas_law(unknown='P', V=1, n=1, R=1, T=1))

gcp.ideal_gas_law(unknown='V', P=10, n=5, R=3, T=2)
# Out:
# 1.0
# 3.0

# %% [markdown]
# ## Practice creating graphs with matplotlib:

# %%
x = [ 1, 2, 3, 4, 5] # place x-values
y = [ 2, 4, 6, 8, 10] #  place y-values
plt.plot(x, y) # set x-y range
plt.title('Simple Line Graph') # Change graph title
plt.xlabel('x axis') # Change x-axis title
plt.ylabel('y axis') # Change y-axis title
plt.show() # Open graph window

# %% [markdown]
# ## Standard temperature and pressure conditions

# %%
pressure = 1 atm

temp = 273.15 K\

1 mol = 6.022 x 10^23 atoms

Vol/mol = 22.4 L

# %% [markdown]
# ## Partial Pressure

# %% [markdown]
# The total pressure in a system is equal to the sum of the individual pressure extered by each gas.

# %% [markdown]
# Attempt to make a partial pressure problem generator**

# %%
num_gases = x
gas_list = []
P_total = sum()

for i in range num_gases:
  P_total += P_i

# %%
select_list = ['H2','He','N2','O2','F2','Cl2','Ne','Ar','Kr','Xe','Rn']
gas_list = random.sample(select_list, 2)
mol_list = []
for i in range (2):
  mol_list.append(round(random.uniform(1.0, 10.0), 2))
P_total = random.randint(5,50)
print(gas_list)
print(mol_list)
print("If there are",mol_list[0],"mols of",gas_list[0],"and there are",mol_list[1],"mols of",gas_list[1],"and the total pressure in the system is",P_total,
"what is the partial pressure of each gas?")

mol_frac_0 = mol_list[0]/sum(mol_list)
mol_frac_1 = mol_list[1]/sum(mol_list)
P_0 = (P_total*mol_frac_0)
P_1 = (P_total*mol_frac_1)
print(f"The partial pressure of {gas_list[0]} is {P_0:.2f} and the partial pressure of {gas_list[1]} is {P_1:.2f}")

# %%
select_list = ['H2','He','N2','O2','F2','Cl2','Ne','Ar','Kr','Xe','Rn']
unit_list = []
gas_list = random.sample(select_list, 2)
mol_list = []
for i in range (2):
  mol_list.append(round(random.uniform(1.0, 10.0), 2))
rand_temp = random.randint(100,1000)
vol = random.randint(1,10)
print(gas_list)
print(mol_list)
print("A",vol,"flask contains a mixture of",mol_list[0],"g of",gas_list[0],"and",
mol_list[1],"g of",gas_list[1],"at a temperature of",rand_temp,
"what is the partial pressure of each gas and what is the total pressure in the flask?")

# %% [markdown]
# Solve problems 1-3:

# %%
gas_list = []

# %% [markdown]
# ## Volume - Tempature Graphs

# %%
x = [ 0,1, 2, 3, 4, 5]
y = [ 0,2, 4, 6, 8, 10]
plt.plot( x, y)
plt.title('Volume/Temperature Graph')
plt.xlabel('Temperature in Kelvin')
plt.ylabel('Volume in L')
plt.show()

# %%
x = [ 1, 2, 3, 4, 5]
y = [ 2, 4, 6, 8, 10]
plt.plot( x, y)
plt.title('Pressure/Volume Graph')
plt.xlabel('Volume in L')
plt.ylabel('Pressure in atm')
plt.show()
