# %% [markdown]
# <a href="https://colab.research.google.com/github/GenChemCoding/templates/blob/main/Notebook_5/Notebook_5.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 5.1 - Gases

# %% [markdown]
# Ideal Gas Law
#
# Stoichiometry

# %% [markdown]
# make graphic where you enter values for concentrations, and show how the collision rate increases
