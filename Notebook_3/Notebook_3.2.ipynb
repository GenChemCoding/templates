# %% [markdown]
# # LaTeX, LaTeX, LaTeX!

# %% [markdown]
# In this notebook, we'll be talking about using LaTeX for notating reactions in chemistry. You'll learn what it the language is, how it is typically used, different applications that allow you to use it, and how it can be used in a Colab or Jupyter notebook environment.
#
# ### Learning Objectives:
# * Understand what LaTeX is
# * Discover different applications that can be used to write LaTeX
# * Understand the limitations and capabilities of LaTeX within a Colab/Jupyter Notebook environment

# %% [markdown]
# ## What is LaTeX?

# %% [markdown]
# LaTeX (pronounced "Lah-Tek" or "Lay-Tek") is a language used for

# %% [markdown]
# ## Data Structures

# %% [markdown]
# Data structres are the ways you can store information
#
# The most common types are:
#
# - String : str(true)
#
# Whenever you type letter in python its assumed you either assigning a variable or calling a function eg. print(), str make sure that it is interpreted as a set of characters, you can also do this simply adding quotations around a word, "True"
#
# - List : [value1, value2]
#
# A list stores comma seperated values, they can be strings or integers.
#
# - Dictionary : { Key1 : Value1, Value2, Key2 : Value3, Value4 }
#
# A dictionary is a made of what are called key-value pairs, they can either be intergers or strings
#
# - Tuple : (value1, value2)
#
# A tuple holds 2 immutable values. Immutable means it cannot be changed after it is created.
