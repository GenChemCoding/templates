# %% [markdown]
# <a href="https://colab.research.google.com/github/mari6-commits/templates/blob/main/Notebook_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Molecules, Moles, and Chemical Equations

# %% [markdown]
# In this notebook, we will be going into depth on what functions are and how to use them. #Change that line to smth else; we will be showing how functions can be created maybe instead of what was written. Before this, you've seen functions from libraries and modules being used to carry out problems. Here, we've created our own and will help you learn how to create your own

# %% [markdown]
# To create a table in python you must make tables and rows seperately.

# %%
import pandas as pd
data = {
    'Column 1' : ['A1','A2','A3'],
    'Column 2' : ['B1','B2','B3'],
    'Column 3' : ['C1','C2','C3'],
}
df = pd.DataFrame(data=data)
df
# Out:
#   Column 1 Column 2 Column 3
# 0       A1       B1       C1
# 1       A2       B2       C2
# 2       A3       B3       C3

# %% [markdown]
# $$\require{mhchem}$$
# $\ce{C(s) + O2(g) -> CO2(g)}$

# %% [markdown]
# $\ce{Na (s) + Cl2 (g) -> NaCl(s)}$

# %% [markdown]
# $\ce{2Na(s) + Cl2(g) -> 2NaCl(s)}$

# %% [markdown]
# Create a table to help you solve this stoichiometry problem.

# %% [markdown]
# ## Find the pertentage yield of...

# %%
Percentage_yield = (actual_yield/theoretical_yield)*100
