# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruben-D-Vasquez/templates/blob/main/Notebook_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Molecules, Moles, and Chemical Equations

# %%
# %%capture
# !pip install pHcalc
# !pip install mendeleev

# %%
import math
import numpy as np
import pHcalc
from pHcalc import Inert, System, pHcalc, Acid
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import Circle
import matplotlib.font_manager as fm
import matplotlib.text as txt
import mendeleev
from mendeleev import element
import random
import pandas as pd

# %% [markdown]
# To create a table in python you must make tables and rows seperately.

# %%
data = {
    'Column 1' : ['A1','A2','A3'],
    'Column 2' : ['B1','B2','B3'],
    'Column 3' : ['C1','C2','C3'],
}
df = pd.DataFrame(data=data)
df
# Out:
#   Column 1 Column 2 Column 3
# 0       A1       B1       C1
# 1       A2       B2       C2
# 2       A3       B3       C3

# %% [markdown]
# $$\require{mhchem}$$
# $\ce{C(s) + O2(g) -> CO2(g)}$

# %% [markdown]
# $\ce{Na (s) + Cl2 (g) -> NaCl(s)}$

# %% [markdown]
# $\ce{2Na(s) + Cl2(g) -> 2NaCl(s)}$

# %% [markdown]
# Create a table to help you solve this stoichiometry problem.

# %% [markdown]
# ## Find the pertentage yield of...

# %%
Percentage_yield = (actual_yield/theoretical_yield)*100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7677/4144857073.py in <cell line: 0>()
# ----> 1 Percentage_yield = (actual_yield/theoretical_yield)*100
#
# NameError: name 'actual_yield' is not defined

# %% [markdown]
# # Determine if the charge is neutral, positive, or negative based on the oxidation states.

# %% [markdown]
# ```
# Metal:,Possible States:
# Se,+3
# Ti,"+2, +3, +4"
# V,"+1, +2, +3, +4, +5"
# Cr,"+2, +3, +6"
# Mn,"+2, +3, +4, +6, +7"
# Fe,"+2, +3, +4, +6"
# Cu,"+2, +3, +4"
# Ni,"+2, +3, +4"
# Cu,"+1, +2"
# Zn,+2
# Y,+3
# Zr,+4
# Nb,"+3,+5"
# Mo,"+3,+4,+5, +6"
# Tc,"+4, +6, +7"
# Ru,"+2, +3, +4, +5, +6, +7, +8, +9"
# ```

# %% [markdown]
# ```
# Metal:,Possible States:
# Rh,"+3, +4, +6"
# Pd,"+2, +3,+4"
# Ag,"+1, +2, +3"
# Cd,+2
# La,+3
# Hf,+4
# Ta,"+4, +5"
# W,"+2, +3, +4, +5, +6"
# Re,"+3, +4, +5, +6, +7"
# Os,"+2, +3, +4, +6, +8"
# Lr,"+2, +3, +4, +6"
# Pt,"+2, +3, +4"
# Au,"+1, +3"
# Hg,"+1, +2"
# ```

# %%
metal_dict = {

}

# %% [markdown]
# # Determine if the atom is an ionic state based on the bohr model

# %%
def create_bohr_model():
  atom = mendeleev.element(random.randint(1,56))
  rand_ion = random.randint(-1,1)
  num_proton = atom.atomic_number + rand_ion
  fig, ax = plt.subplots()

  ax.set_axis_off()
  ax.set_xlim(-3.1,3.1)
  ax.set_ylim(-3.1,3.1)
  ax.autoscale(False)
  ax.set_aspect('equal')

  fp = fm.FontProperties(size='20') # Atomic symbol size
  t = txt.Text(text=atom.symbol, fontproperties=fp, verticalalignment='center', horizontalalignment='center', bbox = dict( visible=False, color='grey')) # Atomic symbol code
  ax.add_artist(t)

  coord_list = [ (0,-1),(0,1),(1,0),(-1,0),(.707,.707),(-.707,.707),(-.707,-.707),(.707,-.707),(.5,.866),(-.5,-.866),
  (-.5,.866),(.5,-.866),(.866,.5),(-.866,.5),(.866,-.5),(-.866,-.5),(.966,-.259),(-.966,.259)]
  coord_list_2 = [tuple(item * 1.5 for item in t) for t in coord_list]
  coord_list_3 = [tuple(item * 2 for item in t) for t in coord_list]
  coord_list_4 = [tuple(item * 2.5 for item in t) for t in coord_list]

  if num_proton > 56:
    print("Error: Element is out of range (atomic number must be 1-56).")
    return
  if num_proton > 0 :
    circle = Circle((0, 0), radius=0.5, fill=False, color='black')
    ax.add_patch(circle)
    for i in range(min(num_proton, 2)):
      circle = Circle((0,-.5 +  i ), radius=0.04, fill=True, color='blue')
      ax.add_patch(circle)
  if num_proton > 2:
    circle = Circle((0, 0), radius=1, fill=False, color='black')
    ax.add_patch(circle)
    for i in range(min(num_proton-2, 8)):
      circle = Circle(((coord_list[i])), radius=0.04, fill=True, color='blue')
      ax.add_patch(circle)
  if num_proton > 10:
    circle = Circle((0, 0), radius=1.5, fill=False, color='black')
    ax.add_patch(circle)
    for i in range(min(num_proton-10, 8)):
      circle = Circle(((coord_list_2[i])), radius=0.04, fill=True, color='blue')
      ax.add_patch(circle)
  if num_proton > 18:
    circle = Circle((0, 0), radius=2, fill=False, color='black')
    ax.add_patch(circle)
    for i in range(min(num_proton-18, 2)):
      circle = Circle((0,-2 + i*4 ), radius=0.04, fill=True, color='blue')
      ax.add_patch(circle)
  if num_proton > 20:
    for i in range(min(num_proton-20,10)):
      circle = Circle(((coord_list_2[i+8])), radius=0.04, fill=True, color='blue')
      ax.add_patch(circle)
  if num_proton > 30:
    for i in range(min(num_proton-30,6)):
      circle = Circle(((coord_list_3[i+2])), radius=0.04, fill=True, color='blue')
      ax.add_patch(circle)
  if num_proton > 36:
    circle = Circle((0, 0), radius=2.5, fill=False, color='black')
    ax.add_patch(circle)
    for i in range(min(num_proton-36,2)):
      circle = Circle((0,-2.5 + i*5 ), radius=0.04, fill=True, color='blue')
      ax.add_patch(circle)
  if num_proton > 38:
    for i in range(min(num_proton-38,10)):
      circle = Circle(((coord_list_3[i+8])), radius=0.04, fill=True, color='blue')
      ax.add_patch(circle)
  if num_proton > 48:
    for i in range(min(num_proton-48,6)):
      circle = Circle(((coord_list_4[i+2])), radius=0.04, fill=True, color='blue')
      ax.add_patch(circle)
  if num_proton > 54:
    circle = Circle((0, 0), radius=3, fill=False, color='black')
    ax.add_patch(circle)
    for i in range(min(num_proton-54,2)):
      circle = Circle((0,-3 + i*6 ), radius=0.04, fill=True, color='blue')
      ax.add_patch(circle)
  if rand_ion != 0:
    print("This is an ion")
    print("It has",rand_ion,"extra electrons")
  else:
    print("This is not an ion")
  plt.show()

create_bohr_model()
# Out:
# This is an ion
# It has -1 extra electrons

# %%
atom = element('Ca') # Create atom variable and call element function with atomic symbol string as its parameter.
elec_config = atom.ec  # Create electron configuration variable and set it to the newly assigned atom varibale calling method .ec
print(elec_config) # print the entire list.
# Out:
# 1s2 2s2 2p6 3s2 3p6 4s2

# %% [markdown]
# Compare the outermost ring to the last few orbitals in the electron configuration to help you indentify if it is an ion.

# %% [markdown]
# # Calculating ph level

# %% [markdown]
# The `pHcalc` library allows you to define a chemical system and calculate its pH by specifying the species present and their concentrations. You typically define species as `Acid` (for acids), `Base` (for bases), or `Inert` (for species that don't directly affect pH but contribute to ionic strength or charge balance).

# %%
# Acids
v = Acid(charge=+1, conc=1.58*10**-9, Ka = .1)
system = System(v)
system.pHsolve()
ph = 14 - system.pH
print(f'{ph}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7677/894923802.py in <cell line: 0>()
#       2 v = Acid(charge=+1, conc=1.58*10**-9, Ka = .1)
#       3 system = System(v)
# ----> 4 system.pHsolve()
#       5 ph = 14 - system.pH
#       6 print(f'{ph}')
#
# /usr/local/lib/python3.12/dist-packages/pHcalc/pHcalc.py in pHsolve(self, guess, guess_est, est_num, method, tol)
#     313             guess = phs[guess_idx]
#     314
# --> 315         self.pHsolution = spo.minimize(self._diff_pos_neg, guess,
#     316                 method=method, tol=tol)
#     317
#
# /usr/local/lib/python3.12/dist-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     770
#     771     if meth == 'nelder-mead':
# --> 772         res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     773                                    **options)
#     774     elif meth == 'powell':
#
# /usr/local/lib/python3.12/dist-packages/scipy/optimize/_optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     849     try:
#     850         for k in range(N + 1):
# --> 851             fsim[k] = func(sim[k])
#     852     except _MaxFuncCallError:
#     853         pass
#
# /usr/local/lib/python3.12/dist-packages/scipy/optimize/_optimize.py in function_wrapper(x, *wrapper_args)
#     558         ncalls[0] += 1
#     559         # A copy of x is sent to the user function (gh13740)
# --> 560         fx = function(np.copy(x), *(wrapper_args + args))
#     561         # Ideally, we'd like to a have a true scalar returned from f(x). For
#     562         # backwards-compatibility, also allow np.array([1.3]),
#
# /usr/local/lib/python3.12/dist-packages/pHcalc/pHcalc.py in _diff_pos_neg(self, pH)
#     255         for s in self.species:
#     256             if twoD == False:
# --> 257                 x += (s.conc*s.charge*s.alpha(pH)).sum()
#     258             else:
#     259                 x += (s.conc*s.charge*s.alpha(pH)).sum(axis=1)
#
# /usr/local/lib/python3.12/dist-packages/pHcalc/pHcalc.py in alpha(self, pH)
#     170         # Calculate a cumulative product of the Ka values. The first value
#     171         # must be 1.0, which is why _Ka_temp is used instead of Ka.
# --> 172         Ka_prod = np.cumproduct(self._Ka_temp)
#     173         # Multiply the H3O**power values times the cumulative Ka product.
#     174         h3o_Ka = h3o_pow*Ka_prod
#
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py in __getattr__(attr)
#     408             return char.chararray
#     409
# --> 410         raise AttributeError("module {!r} has no attribute "
#     411                              "{!r}".format(__name__, attr))
#     412
#
# AttributeError: module 'numpy' has no attribute 'cumproduct'

# %%
# Bases
v = Inert(charge=+1, conc=1.58*10**-9)
system = System(v)
system.pHsolve()
ph = 14 - system.pH
print(f'{ph}')
# Out:
# 6.996571350097656

# %%
ph = -log[H^+] # [H^+] is the concentration of the hydrogen ions
molarity = n mol/vol
[H+][OH-] = 1*10^-14

# %%
c =
ph = -1*math.log10(c)

# %% [markdown]
# # Challange: Create a function that takes an equilibrium reaction and turns it into an ICE chart.
#
# Your code should include an if-else statment so that it can change whether the left or right side of the reaction has 1 or 2 compounds.

# %%
data = {
    '' : ['Initial','Change','Equilibirum'],
    '[]1' : ['B1','B2','B3'],
    '[]2' : ['C1','C2','C3'],
    '[]3' : ['D1','D2','D3'],
    '<-->': [ "" ,"",""],
    '[]4' : ['E1','E2','E3'],
}
df = pd.DataFrame(data=data)
df
# Out:
#                []1 []2 []3 <--> []4
# 0      Initial  B1  C1  D1       E1
# 1       Change  B2  C2  D2       E2
# 2  Equilibirum  B3  C3  D3       E3

# %% [markdown]
# # Chemical formulas and how they can be represented multiple ways based on a multiples and what moles are.**

# %%
empirical compund  = simplest form
Molecular = distributed form

# %%
M =  n_mol/vol

# %%
1 mol = 6.022*10^23 atoms
c6h12c6 = 6 ch2c

# %%
def mol_to_atm(mol):

# %% [markdown]
# Given (mols of compound)...

# %% [markdown]
# ## Convert the written chemcial formula into symbolic form and vice versa

# %%
Barium Phospahte -> Ba3(PO4)2

# %%
def conv_sym_to_form(symbol):

# %%
def conv_elem_to_sym(element):
  if element == 'Hydrogen':
    return 'H'
  if element == 'Helium':
    return 'He'
conv_elem_to_sym('Hydrogen')
# Out:
# 'H'

# %% [markdown]
# Try to create a function that returns the correct symbol for a given element. For this excersize 3 elements should suffice.
