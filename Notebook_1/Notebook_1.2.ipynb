# %% [markdown]
# # 1.2 - Introduction to Python

# %% [markdown]
# ## Learning Objectives:
#
# *
# *

# %% [markdown]
# ### Data types:

# %% [markdown]
# ### Variables:

# %% [markdown]
# ### Printing:

# %% [markdown]
# ### Arithmetic:
