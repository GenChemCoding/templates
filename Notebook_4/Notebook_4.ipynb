# %% [markdown]
# <a href="https://colab.research.google.com/github/GenChemCoding/templates/blob/main/Notebook_4/Notebook_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4.1 - Stoichiometry

# %% [markdown]
# Stoichiometry of mass to mass conversions
#
# Stoichiometry of solvent
#
# Finding limiting reactants
